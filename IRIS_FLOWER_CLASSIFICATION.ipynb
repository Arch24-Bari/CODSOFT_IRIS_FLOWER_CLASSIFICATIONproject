# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#ingestingdata
df = pd.read_csv('IRIS.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.sample(6)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 78            6.0          2.9           4.5          1.5  Iris-versicolor
# 121           5.6          2.8           4.9          2.0   Iris-virginica
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 18            5.7          3.8           1.7          0.3      Iris-setosa
# 127           6.1          3.0           4.9          1.8   Iris-virginica
# 135           7.7          3.0           6.1          2.3   Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#multi class classification problem, target vaiable = 'species' >> object type
#object needs to be converted to int type
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width     species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    1.000000
# std        0.828066     0.433594      1.764420     0.763161    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
df['species'].value_counts() #no case for class imbalance
# Out:
# species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
df.info() #with no null entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %% [markdown]
# **Data Visualisation**
#
# ----Univariate Analysis-----

# %%
plt.title('Distribution of Sepal width')
sns.histplot(df['sepal_width'], kde = True)
# greater no. of flower species having sepal width around 2.5 and 3.5, roughly normally distribtd data
# few outliers present
# Out:
# <Axes: title={'center': 'Distribution of Sepal width'}, xlabel='sepal_width', ylabel='Count'>

# %%
plt.title('Distribution of Sepal length')
sns.histplot(df['sepal_length'], kde = True)
#multi modal distribuion, different grps within the data with distinct sepal lengths
# Out:
# <Axes: title={'center': 'Distribution of Sepal length'}, xlabel='sepal_length', ylabel='Count'>

# %%
plt.title('Distribution of petal length')
sns.histplot(df['petal_length'], kde = True)
#2 main grp of flowers with different petal length, bimodal distribution
# Out:
# <Axes: title={'center': 'Distribution of petal length'}, xlabel='petal_length', ylabel='Count'>

# %%
plt.title('Distribution of Petal width')
sns.histplot(df['sepal_width'], kde = True)
#normal distribution with a very outliers
# Out:
# <Axes: title={'center': 'Distribution of Petal width'}, xlabel='sepal_width', ylabel='Count'>

# %% [markdown]
# ----Multivariate Analysis-----

# %%
sns.pairplot(df,hue='species')
# preliminary conclusion = direct propotionality of each feature with the other (roughly)

# %%
sns.pairplot(df, hue='species',x_vars=['sepal_length', 'sepal_width','petal_length', 'petal_width'], y_vars='species')
# analysis = petal length and petal width show clearer separation between the species compared to sepal length and sepal width.

# %%
#Confirmation of correlation using a heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split
X = df.drop('species', axis = 1)
y = df['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
l_a = accuracy_score(y_test, y_pred)
print('ACCURACY SCORE')
print(accuracy_score(y_test, y_pred))
print('\n')
print('CONFUSION MATRIX')
print(confusion_matrix(y_test, y_pred))
print('\n')
print('CLASSIFICATION REPORT')
print(classification_report(y_test, y_pred))
# Out:
# ACCURACY SCORE
# 1.0
#
#
# CONFUSION MATRIX
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
#
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)

# %%
d_a = accuracy_score(y_test, y_pred)
print('ACCURACY SCORE')
print(accuracy_score(y_test, y_pred))
print('\n')
print('CONFUSION MATRIX')
print(confusion_matrix(y_test, y_pred))
print('\n')
print('CLASSIFICATION REPORT')
print(classification_report(y_test, y_pred))
# Out:
# ACCURACY SCORE
# 1.0
#
#
# CONFUSION MATRIX
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
#
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
plot_tree(dt, feature_names = X.columns, class_names = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], filled = True)
plt.title('Decision Tree for classification into species')
# Out:
# Text(0.5, 1.0, 'Decision Tree for classification into species')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %%
k_a = accuracy_score(y_test, y_pred)
print('ACCURACY SCORE')
print(accuracy_score(y_test, y_pred))
print('\n')
print('CONFUSION MATRIX')
print(confusion_matrix(y_test, y_pred))
print('\n')
print('CLASSIFICATION REPORT')
print(classification_report(y_test, y_pred))
# Out:
# ACCURACY SCORE
# 1.0
#
#
# CONFUSION MATRIX
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
#
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
plt.title('Model accuracy comparison')
plt.bar(['linear regression','decision tree','kNN classifier'], [l_a, d_a,k_a], color = ['red', 'green', 'blue'])
plt.show()
# all models show accuracy of 100%

# %%
predctd_species_encoded = lr.predict([[5.1, 2.6, 3.1, 2.8]])
predctd_species_name = le.inverse_transform(predctd_species_encoded)
predctd_species_name
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Iris-versicolor'], dtype=object)
